# %%
# 1. Importar las librerías necesarias para crear la conexión y trbajar con Pandas.

# %%
# Importar librería para la conexión con MySQL
# -----------------------------------------------------------------------
import mysql.connector
from mysql.connector import errorcode


# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# %%
# 2. Crear la conexión a la base de datos Northwind que devuelva un mensaje de error si algo no ocurre cómo debería.

# %%
# ahora creamos la conexión con los argumentos:

cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='northwind')

print(cnx)
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x0000019087AB5250>

# %%
# En este código estamos haciendo un try except. Si recordamos esto nos permitía hacer un manejo de los errores, para evitar que nuestro código se pare. Para eso lo que estamos haciendo es
## intenta hacer la conexión son la base de datos de tienda 
try:
  cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='northwind')
# en caso de que no lo consigas por que hay algún error entonces ...
except mysql.connector.Error as err:

  # si es un error con la contraseña devuelveme un mensaje de acceso denegado ya que tenemos problemas con la contraseña
  if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
    print("Something is wrong with your user name or password")
  
  # si el error no tiene que ver con la contraseña, puede ser porque la base de datos no exista, devuelveme un mensaje de que la base de datos no existe
  elif err.errno == errorcode.ER_BAD_DB_ERROR:
    print("Database does not exist")
  
  # si no es por ninguno de los errores anteriores, printeame cual es el error que estoy teniendo en mi conexión
  else:
    print(err)
else:

# %%
# iniciamos el cursor                               
mycursor = cnx.cursor()

# %%
mycursor.execute("""SHOW COLUMNS FROM CUSTOMERS""")

# %%
# 3. Usando "information_schema", extraer los nombres de las columnas de la tabla "customers" de la BBDD "northwind".

# %%
for col in mycursor: # extraemos el nombres de las columnas. version 1
    print (col[0])
# Out:
# customer_id
# company_name
# contact_name
# contact_title
# address
# city
# region
# postal_code
# country
# phone
# fax

# %%
columnas = mycursor.fetchall() # extraemos el nombres de las columnas. version 2

# %%
print(columnas)
# Out:
# []

# %%
# 4. Seleccionar todo de la tabla "customers" donde "country" sea "USA" o "Germany". Almacenar los resultados en una variable.

cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='northwind')

print(cnx)

# iniciamos el cursor                               
mycursor = cnx.cursor()

query = ("""SELECT *
            FROM CUSTOMERS
            WHERE `country` = 'USA' OR 'Germany' """)

mycursor.execute(query)
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x0000019087F2D250>

# %%
resultados_paises = mycursor.fetchall()

# %%
print(resultados_paises)
# Out:
# [('GREAL', 'Great Lakes Food Market', 'Howard Snyder', 'Marketing Manager', '2732 Baker Blvd.', 'Eugene', 'OR', '97403', 'USA', '(503) 555-7555', ''), ('HUNGC', 'Hungry Coyote Import Store', 'Yoshi Latimer', 'Sales Representative', 'City Center Plaza 516 Main St.', 'Elgin', 'OR', '97827', 'USA', '(503) 555-6874', '(503) 555-2376'), ('LAZYK', 'Lazy K Kountry Store', 'John Steel', 'Marketing Manager', '12 Orchestra Terrace', 'Walla Walla', 'WA', '99362', 'USA', '(509) 555-7969', '(509) 555-6221'), ('LETSS', "Let's Stop N Shop", 'Jaime Yorres', 'Owner', '87 Polk St. Suite 5', 'San Francisco', 'CA', '94117', 'USA', '(415) 555-5938', ''), ('LONEP', 'Lonesome Pine Restaurant', 'Fran Wilson', 'Sales Manager', '89 Chiaroscuro Rd.', 'Portland', 'OR', '97219', 'USA', '(503) 555-9573', '(503) 555-9646'), ('OLDWO', 'Old World Delicatessen', 'Rene Phillips', 'Sales Representative', '2743 Bering St.', 'Anchorage', 'AK', '99508', 'USA', '(907) 555-7584', '(907) 555-2880'), ('RATTC', 'Rattlesnake Canyon Grocery', 'Paula Wilson', 'Assistant Sales Representative', '2817 Milton Dr.', 'Albuquerque', 'NM', '87110', 'USA', '(505) 555-5939', '(505) 555-3620'), ('SAVEA', 'Save-a-lot Markets', 'Jose Pavarotti', 'Sales Representative', '187 Suffolk Ln.', 'Boise', 'ID', '83720', 'USA', '(208) 555-8097', ''), ('SPLIR', 'Split Rail Beer & Ale', 'Art Braunschweiger', 'Sales Manager', 'P.O. Box 555', 'Lander', 'WY', '82520', 'USA', '(307) 555-4680', '(307) 555-6525'), ('THEBI', 'The Big Cheese', 'Liz Nixon', 'Marketing Manager', '89 Jefferson Way Suite 2', 'Portland', 'OR', '97201', 'USA', '(503) 555-3612', ''), ('THECR', 'The Cracker Box', 'Liu Wong', 'Marketing Assistant', '55 Grizzly Peak Rd.', 'Butte', 'MT', '59801', 'USA', '(406) 555-5834', '(406) 555-8083'), ('TRAIH', "Trail's Head Gourmet Provisioners", 'Helvetius Nagy', 'Sales Associate', '722 DaVinci Blvd.', 'Kirkland', 'WA', '98034', 'USA', '(206) 555-8257', '(206) 555-2174'), ('WHITC', 'White Clover Markets', 'Karl Jablonski', 'Owner', '305 - 14th Ave. S. Suite 3B', 'Seattle', 'WA', '98128', 'USA', '(206) 555-4112', '(206) 555-4115')]

# %%
# 5. Convertir los resultados del ejercicio anterior en un Dataframe (no od olvidéis de poner el nombre a las columnas en el orden correcto).

# %%
df = pd.read_sql_query(query, cnx)
# Out:
# C:\Users\asand\AppData\Local\Temp\ipykernel_292\2579736473.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, cnx)

# %%
# 6. Muestrar las 10 primeras filas del Dataframe y las 10 últimas

# %%
df.head(10)
# Out:
#   customer_id                company_name        contact_name  \
# 0       GREAL     Great Lakes Food Market       Howard Snyder
# 1       HUNGC  Hungry Coyote Import Store       Yoshi Latimer
# 2       LAZYK        Lazy K Kountry Store          John Steel
# 3       LETSS           Let's Stop N Shop        Jaime Yorres
# 4       LONEP    Lonesome Pine Restaurant         Fran Wilson
# 5       OLDWO      Old World Delicatessen       Rene Phillips
# 6       RATTC  Rattlesnake Canyon Grocery        Paula Wilson
# 7       SAVEA          Save-a-lot Markets      Jose Pavarotti
# 8       SPLIR       Split Rail Beer & Ale  Art Braunschweiger
# 9       THEBI              The Big Cheese           Liz Nixon
#
#                     contact_title                         address  \
# 0               Marketing Manager                2732 Baker Blvd.
# 1            Sales Representative  City Center Plaza 516 Main St.
# 2               Marketing Manager            12 Orchestra Terrace
# 3                           Owner             87 Polk St. Suite 5
# 4                   Sales Manager              89 Chiaroscuro Rd.
# 5            Sales Representative                 2743 Bering St.
# 6  Assistant Sales Representative                 2817 Milton Dr.
# 7            Sales Representative                 187 Suffolk Ln.
# 8                   Sales Manager                    P.O. Box 555
# 9               Marketing Manager        89 Jefferson Way Suite 2
#
#             city region postal_code country           phone             fax
# 0         Eugene     OR       97403     USA  (503) 555-7555
# 1          Elgin     OR       97827     USA  (503) 555-6874  (503) 555-2376
# 2    Walla Walla     WA       99362     USA  (509) 555-7969  (509) 555-6221
# 3  San Francisco     CA       94117     USA  (415) 555-5938
# 4       Portland     OR       97219     USA  (503) 555-9573  (503) 555-9646
# 5      Anchorage     AK       99508     USA  (907) 555-7584  (907) 555-2880
# 6    Albuquerque     NM       87110     USA  (505) 555-5939  (505) 555-3620
# 7          Boise     ID       83720     USA  (208) 555-8097
# 8         Lander     WY       82520     USA  (307) 555-4680  (307) 555-6525
# 9       Portland     OR       97201     USA  (503) 555-3612

# %%
df.tail(10)
# Out:
#    customer_id                       company_name        contact_name  \
# 3        LETSS                  Let's Stop N Shop        Jaime Yorres
# 4        LONEP           Lonesome Pine Restaurant         Fran Wilson
# 5        OLDWO             Old World Delicatessen       Rene Phillips
# 6        RATTC         Rattlesnake Canyon Grocery        Paula Wilson
# 7        SAVEA                 Save-a-lot Markets      Jose Pavarotti
# 8        SPLIR              Split Rail Beer & Ale  Art Braunschweiger
# 9        THEBI                     The Big Cheese           Liz Nixon
# 10       THECR                    The Cracker Box            Liu Wong
# 11       TRAIH  Trail's Head Gourmet Provisioners      Helvetius Nagy
# 12       WHITC               White Clover Markets      Karl Jablonski
#
#                      contact_title                      address  \
# 3                            Owner          87 Polk St. Suite 5
# 4                    Sales Manager           89 Chiaroscuro Rd.
# 5             Sales Representative              2743 Bering St.
# 6   Assistant Sales Representative              2817 Milton Dr.
# 7             Sales Representative              187 Suffolk Ln.
# 8                    Sales Manager                 P.O. Box 555
# 9                Marketing Manager     89 Jefferson Way Suite 2
# 10             Marketing Assistant          55 Grizzly Peak Rd.
# 11                 Sales Associate            722 DaVinci Blvd.
# 12                           Owner  305 - 14th Ave. S. Suite 3B
#
#              city region postal_code country           phone             fax
# 3   San Francisco     CA       94117     USA  (415) 555-5938
# 4        Portland     OR       97219     USA  (503) 555-9573  (503) 555-9646
# 5       Anchorage     AK       99508     USA  (907) 555-7584  (907) 555-2880
# 6     Albuquerque     NM       87110     USA  (505) 555-5939  (505) 555-3620
# 7           Boise     ID       83720     USA  (208) 555-8097
# 8          Lander     WY       82520     USA  (307) 555-4680  (307) 555-6525
# 9        Portland     OR       97201     USA  (503) 555-3612
# 10          Butte     MT       59801     USA  (406) 555-5834  (406) 555-8083
# 11       Kirkland     WA       98034     USA  (206) 555-8257  (206) 555-2174
# 12        Seattle     WA       98128     USA  (206) 555-4112  (206) 555-4115

# %%
# 7. Mostrar 5 filas aleatorias del Dataframe.

# %%
df.sample(7)
# Out:
#    customer_id                company_name    contact_name  \
# 0        GREAL     Great Lakes Food Market   Howard Snyder
# 4        LONEP    Lonesome Pine Restaurant     Fran Wilson
# 6        RATTC  Rattlesnake Canyon Grocery    Paula Wilson
# 3        LETSS           Let's Stop N Shop    Jaime Yorres
# 12       WHITC        White Clover Markets  Karl Jablonski
# 1        HUNGC  Hungry Coyote Import Store   Yoshi Latimer
# 2        LAZYK        Lazy K Kountry Store      John Steel
#
#                      contact_title                         address  \
# 0                Marketing Manager                2732 Baker Blvd.
# 4                    Sales Manager              89 Chiaroscuro Rd.
# 6   Assistant Sales Representative                 2817 Milton Dr.
# 3                            Owner             87 Polk St. Suite 5
# 12                           Owner     305 - 14th Ave. S. Suite 3B
# 1             Sales Representative  City Center Plaza 516 Main St.
# 2                Marketing Manager            12 Orchestra Terrace
#
#              city region postal_code country           phone             fax
# 0          Eugene     OR       97403     USA  (503) 555-7555
# 4        Portland     OR       97219     USA  (503) 555-9573  (503) 555-9646
# 6     Albuquerque     NM       87110     USA  (505) 555-5939  (505) 555-3620
# 3   San Francisco     CA       94117     USA  (415) 555-5938
# 12        Seattle     WA       98128     USA  (206) 555-4112  (206) 555-4115
# 1           Elgin     OR       97827     USA  (503) 555-6874  (503) 555-2376
# 2     Walla Walla     WA       99362     USA  (509) 555-7969  (509) 555-6221

# %%
# 8. ¿Hay nulos en el Dataframe? El resultado debe verse para cada una de las columnas.

# %%
df.isnull().sum()
# Out:
# customer_id      0
# company_name     0
# contact_name     0
# contact_title    0
# address          0
# city             0
# region           0
# postal_code      0
# country          0
# phone            0
# fax              0
# dtype: int64

# %%
# 9. Mostrar los principales estadísticos.

# %%
df.describe() #No hay datos INT ni FLOAT, nos devuelve los categóricos
# Out:
#        customer_id             company_name   contact_name      contact_title  \
# count           13                       13             13                 13
# unique          13                       13             13                  7
# top          GREAL  Great Lakes Food Market  Howard Snyder  Marketing Manager
# freq             1                        1              1                  3
#
#                  address      city region postal_code country           phone  \
# count                 13        13     13          13      13              13
# unique                13        12      8          13       1              13
# top     2732 Baker Blvd.  Portland     OR       97403     USA  (503) 555-7555
# freq                   1         2      4           1      13               1
#
#        fax
# count   13
# unique  10
# top
# freq     4

# %%
# 10. Mostrar el nombre de las columnas del Dataframe.

# %%
df.columns
# Out:
# Index(['customer_id', 'company_name', 'contact_name', 'contact_title',
#        'address', 'city', 'region', 'postal_code', 'country', 'phone', 'fax'],
#       dtype='object')
