# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

df_world_data_total = pd.read_csv("data/df_world_data_total.csv", index_col = 0) # el merge de los dos world-data

# %%
df_world_data_total
# Out:
#             density abbreviation  agriculturalland   landarea armedforcessize  \
# country
# Afghanistan      60           AF              58.1    652,230         323,000
# Albania         105           AL              43.1     28,748           9,000
# Algeria          18           DZ              17.4  2,381,741         317,000
# Andorra         164           AD              40.0        468             NaN
# Angola           26           AO              47.5  1,246,700         117,000
# ...             ...          ...               ...        ...             ...
# Venezuela        32           VE              24.5    912,050         343,000
# Vietnam         314           VN              39.3    331,210         522,000
# Yemen            56           YE              44.6    527,968          40,000
# Zambia           25           ZM              32.1    752,618          16,000
# Zimbabwe         38           ZW              41.9    390,757          51,000
#
#              birthrate  callingcode capital/majorcity co2-emissions       cpi  \
# country
# Afghanistan      32.49         93.0             Kabul         8,672     149.9
# Albania          11.78        355.0            Tirana         4,536    119.05
# Algeria          24.28        213.0           Algiers       150,006    151.36
# Andorra           7.20        376.0  Andorra la Vella           469       NaN
# Angola           40.73        244.0            Luanda        34,693    261.73
# ...                ...          ...               ...           ...       ...
# Venezuela        17.88         58.0           Caracas       164,175  2,740.27
# Vietnam          16.75         84.0             Hanoi       192,668    163.52
# Yemen            30.45        967.0             Sanaa        10,609    157.58
# Zambia           36.19        260.0            Lusaka         5,141    212.31
# Zimbabwe         30.68        263.0            Harare        10,983    105.51
#
#              cpichange currency-code  fertilityrate  forestedarea  \
# country
# Afghanistan        2.3           AFN           4.47           2.1
# Albania            1.4           ALL           1.62          28.1
# Algeria            2.0           DZD           3.02           0.8
# Andorra            NaN           EUR           1.27          34.0
# Angola            17.1           AOA           5.52          46.3
# ...                ...           ...            ...           ...
# Venezuela        254.9           VED           2.27          52.7
# Vietnam            2.8           VND           2.05          48.1
# Yemen              8.1           YER           3.79           1.0
# Zambia             9.2           ZMW           4.63          65.2
# Zimbabwe           0.9           NaN           3.62          35.5
#
#              gasolineprice               gdp  grossprimaryeducationenrollment  \
# country
# Afghanistan           0.70   19,101,353,833                             104.0
# Albania               1.36   15,278,077,447                             107.0
# Algeria               0.28  169,988,236,398                             109.9
# Andorra               1.51    3,154,057,987                             106.4
# Angola                0.97   94,635,415,870                             113.5
# ...                    ...               ...                              ...
# Venezuela             0.00  482,359,318,768                              97.2
# Vietnam               0.80  261,921,244,843                             110.6
# Yemen                 0.92   26,914,402,224                              93.6
# Zambia                1.40   23,064,722,446                              98.7
# Zimbabwe              1.34   21,440,758,800                             109.9
#
#              grosstertiaryeducationenrollment  infantmortality  \
# country
# Afghanistan                               9.7             47.9
# Albania                                  55.0              7.8
# Algeria                                  51.4             20.1
# Andorra                                   NaN              2.7
# Angola                                    9.3             51.6
# ...                                       ...              ...
# Venezuela                                79.3             21.4
# Vietnam                                  28.5             16.5
# Yemen                                    10.2             42.9
# Zambia                                    4.1             40.4
# Zimbabwe                                 10.0             33.9
#
#                   largestcity  lifeexpectancy  maternalmortalityratio  \
# country
# Afghanistan             Kabul            64.5                   638.0
# Albania                Tirana            78.5                    15.0
# Algeria               Algiers            76.7                   112.0
# Andorra      Andorra la Vella             NaN                     NaN
# Angola                 Luanda            60.8                   241.0
# ...                       ...             ...                     ...
# Venezuela             Caracas            72.1                   125.0
# Vietnam      Ho Chi Minh City            75.3                    43.0
# Yemen                   Sanaa            66.1                   164.0
# Zambia                 Lusaka            63.5                   213.0
# Zimbabwe               Harare            61.2                   458.0
#
#              minimumwage officiallanguage  outofpockethealthexpenditure  \
# country
# Afghanistan         0.43           Pashto                          78.4
# Albania             1.12         Albanian                          56.9
# Algeria             0.95           Arabic                          28.1
# Andorra             6.63          Catalan                          36.4
# Angola              0.71       Portuguese                          33.4
# ...                  ...              ...                           ...
# Venezuela           0.01          Spanish                          45.8
# Vietnam             0.73       Vietnamese                          43.5
# Yemen                NaN           Arabic                          81.0
# Zambia              0.24          English                          27.5
# Zimbabwe             NaN            Shona                          25.8
#
#              physiciansperthousand  population  \
# country
# Afghanistan                   0.28  38,041,754
# Albania                       1.20   2,854,191
# Algeria                       1.72  43,053,054
# Andorra                       3.33      77,142
# Angola                        0.21  31,825,295
# ...                            ...         ...
# Venezuela                     1.92  28,515,829
# Vietnam                       0.82  96,462,106
# Yemen                         0.31  29,161,922
# Zambia                        1.19  17,861,030
# Zimbabwe                      0.21  14,645,468
#
#              populationlaborforceparticipation  taxrevenue  totaltaxrate  \
# country
# Afghanistan                               48.9         9.3          71.4
# Albania                                   55.7        18.6          36.6
# Algeria                                   41.2        37.2          66.1
# Andorra                                    NaN         NaN           NaN
# Angola                                    77.5         9.2          49.1
# ...                                        ...         ...           ...
# Venezuela                                 59.7         NaN          73.3
# Vietnam                                   77.4        19.1          37.6
# Yemen                                     38.0         NaN          26.6
# Zambia                                    74.6        16.2          15.6
# Zimbabwe                                  83.1        20.7          31.6
#
#              unemploymentrate urban_population         latitud        longitud
# country
# Afghanistan             11.12        9,797,273    ('33.93911 '    '67.709953')
# Albania                 12.33        1,747,593   ('41.153332 '    '20.168331')
# Algeria                 11.70       31,510,100   ('28.033886 '     '1.659626')
# Andorra                   NaN           67,873   ('42.506285 '     '1.521801')
# Angola                   6.89       21,061,025  ('-11.202692 '    '17.873887')
# ...                       ...              ...             ...             ...
# Venezuela                8.80       25,162,368     ('6.42375 '    '-66.58973')
# Vietnam                  2.01       35,332,140   ('14.058324 '   '108.277199')
# Yemen                   12.91       10,869,523   ('15.552727 '    '48.516388')
# Zambia                  11.43        7,871,713  ('-13.133897 '    '27.849332')
# Zimbabwe                 4.95        4,717,305  ('-19.015438 '    '29.154857')
#
# [195 rows x 34 columns]

# %% [markdown]
# Ejercicios apply

# %% [markdown]
# 1.Las columnas land_area, armed_forces_size, co2-emissions, gdp, population, urban_population, latitude, longitude, density, cpi son de tipo object pero en realidad deberían ser numéricas. Crea una función que nos permita cambiar el tipo de dato de estas columnas al que le corresponde.

# %%
df_world_data_total.columns
# Out:
# Index(['density', 'abbreviation', 'agriculturalland', 'landarea',
#        'armedforcessize', 'birthrate', 'callingcode', 'capital/majorcity',
#        'co2-emissions', 'cpi', 'cpichange', 'currency-code', 'fertilityrate',
#        'forestedarea', 'gasolineprice', 'gdp',
#        'grossprimaryeducationenrollment', 'grosstertiaryeducationenrollment',
#        'infantmortality', 'largestcity', 'lifeexpectancy',
#        'maternalmortalityratio', 'minimumwage', 'officiallanguage',
#        'outofpockethealthexpenditure', 'physiciansperthousand', 'population',
#        'populationlaborforceparticipation', 'taxrevenue', 'totaltaxrate',
#        'unemploymentrate', 'urban_population', 'latitud', 'longitud'],
#       dtype='object')

# %%
df_world_data_total["latitud"]=df_world_data_total["latitud"].str.replace("(","").str.replace("'","")
df_world_data_total["longitud"]=df_world_data_total["longitud"].str.replace(")","").str.replace("'","")

# %%
def convertir_numerica(valor):
    try:
        return float(valor.replace(",",""))
    except:
        return valor
        

columnas_a_convertir=[ "landarea", "armedforcessize", "co2-emissions", "gdp", "population", "urban_population", "latitud", "longitud", "density", "cpi"]

for columna in columnas_a_convertir:
    df_world_data_total[columna]=df_world_data_total[columna].apply(convertir_numerica)

# %% [markdown]
# 2.Crea una función para añadir una nueva columna llamada 'Continent' al DataFrame para indicar a qué continente pertenece cada país.

# %%
df_world_data_total=df_world_data_total.reset_index()

# %%
country_continents = {
    'Afghanistan': 'Asia',
    'Albania': 'Europe',
    'Algeria': 'Africa',
    'Andorra': 'Europe',
    'Angola': 'Africa',
    'Antigua and Barbuda': 'North America',
    'Argentina': 'South America',
    'Armenia': 'Asia',
    'Australia': 'Oceania',
    'Austria': 'Europe',
    'Azerbaijan': 'Asia',
    'The Bahamas': 'North America',
    'Bahrain': 'Asia',
    'Bangladesh': 'Asia',
    'Barbados': 'North America',
    'Belarus': 'Europe',
    'Belgium': 'Europe',
    'Belize': 'North America',
    'Benin': 'Africa',
    'Bhutan': 'Asia',
    'Bolivia': 'South America',
    'Bosnia and Herzegovina': 'Europe',
    'Botswana': 'Africa',
    'Brazil': 'South America',
    'Brunei': 'Asia',
    'Bulgaria': 'Europe',
    'Burkina Faso': 'Africa',
    'Burundi': 'Africa',
    'Ivory Coast': 'Africa',
    'Cape Verde': 'Africa',
    'Cambodia': 'Asia',
    'Cameroon': 'Africa',
    'Canada': 'North America',
    'Central African Republic': 'Africa',
    'Chad': 'Africa',
    'Chile': 'South America',
    'China': 'Asia',
    'Colombia': 'South America',
    'Comoros': 'Africa',
    'Republic of the Congo': 'Africa',
    'Costa Rica': 'North America',
    'Croatia': 'Europe',
    'Cuba': 'North America',
    'Cyprus': 'Asia',
    'Czech Republic': 'Europe',
    'Democratic Republic of the Congo': 'Africa',
    'Denmark': 'Europe',
    'Djibouti': 'Africa',
    'Dominica': 'North America',
    'Dominican Republic': 'North America',
    'Ecuador': 'South America',
    'Egypt': 'Africa',
    'El Salvador': 'North America',
    'Equatorial Guinea': 'Africa',
    'Eritrea': 'Africa',
    'Estonia': 'Europe',
    'Eswatini': 'Africa',
    'Ethiopia': 'Africa',
    'Fiji': 'Oceania',
    'Finland': 'Europe',
    'France': 'Europe',
    'Gabon': 'Africa',
    'The Gambia': 'Africa',
    'Georgia': 'Asia',
    'Germany': 'Europe',
    'Ghana': 'Africa',
    'Greece': 'Europe',
    'Grenada': 'North America',
    'Guatemala': 'North America',
    'Guinea': 'Africa',
    'Guinea-Bissau': 'Africa',
    'Guyana': 'South America',
    'Haiti': 'North America',
    'Vatican City': 'Europe',
    'Honduras': 'North America',
    'Hungary': 'Europe',
    'Iceland': 'Europe',
    'India': 'Asia',
    'Indonesia': 'Asia',
    'Iran': 'Asia',
    'Iraq': 'Asia',
    'Republic of Ireland': 'Europe',
    'Israel': 'Asia',
    'Italy': 'Europe',
    'Jamaica': 'North America',
    'Japan': 'Asia',
    'Jordan': 'Asia',
    'Kazakhstan': 'Asia',
    'Kenya': 'Africa',
    'Kiribati': 'Oceania',
    'Kuwait': 'Asia',
    'Kyrgyzstan': 'Asia',
    'Laos': 'Asia',
    'Latvia': 'Europe',
    'Lebanon': 'Asia',
    'Lesotho': 'Africa',
    'Liberia': 'Africa',
    'Libya': 'Africa',
    'Liechtenstein': 'Europe',
    'Lithuania': 'Europe',
    'Luxembourg': 'Europe',
    'Madagascar': 'Africa',
    'Malawi': 'Africa',
    'Malaysia': 'Asia',
    'Maldives': 'Asia',
    'Mali': 'Africa',
    'Malta': 'Europe',
    'Marshall Islands': 'Oceania',
    'Mauritania': 'Africa',
    'Mauritius': 'Africa',
    'Mexico': 'North America',
    'Federated States of Micronesia': 'Oceania',
    'Moldova': 'Europe',
    'Monaco': 'Europe',
    'Mongolia': 'Asia',
    'Montenegro': 'Europe',
    'Morocco': 'Africa',
    'Mozambique': 'Africa',
    'Myanmar': 'Asia',
    'Namibia': 'Africa',
    'Nauru': 'Oceania',
    'Nepal': 'Asia',
    'Netherlands': 'Europe',
    'New Zealand': 'Oceania',
    'Nicaragua': 'North America',
    'Niger': 'Africa',
    'Nigeria': 'Africa',
    'North Korea': 'Asia',
    'North Macedonia': 'Europe',
    'Norway': 'Europe',
    'Oman': 'Asia',
    'Pakistan': 'Asia',
    'Palau': 'Oceania',
    'Palestinian National Authority': 'Asia',
    'Panama': 'North America',
    'Papua New Guinea': 'Oceania',
    'Paraguay': 'South America',
    'Peru': 'South America',
    'Philippines': 'Asia',
    'Poland': 'Europe',
    'Portugal': 'Europe',
    'Qatar': 'Asia',
    'Romania': 'Europe',
    'Russia': 'Europe',
    'Rwanda': 'Africa',
    'Saint Kitts and Nevis': 'North America',
    'Saint Lucia': 'North America',
    'Saint Vincent and the Grenadines': 'North America',
    'Samoa': 'Oceania',
    'San Marino': 'Europe',
    'São Tomé and Príncipe': 'Africa',
    'Saudi Arabia': 'Asia',
    'Senegal': 'Africa',
    'Serbia': 'Europe',
    'Seychelles': 'Africa',
    'Sierra Leone': 'Africa',
    'Singapore': 'Asia',
    'Slovakia': 'Europe',
    'Slovenia': 'Europe',
    'Solomon Islands': 'Oceania',
    'Somalia': 'Africa',
    'South Africa': 'Africa',
    'South Korea': 'Asia',
    'South Sudan': 'Africa',
    'Spain': 'Europe',
    'Sri Lanka': 'Asia',
    'Sudan': 'Africa',
    'Suriname': 'South America',
    'Sweden': 'Europe',
    'Switzerland': 'Europe',
    'Syria': 'Asia',
    'Tajikistan': 'Asia',
    'Tanzania': 'Africa',
    'Thailand': 'Asia',
    'East Timor': 'Asia',
    'Togo': 'Africa',
    'Tonga': 'Oceania',
    'Trinidad and Tobago': 'North America',
    'Tunisia': 'Africa',
    'Turkey': 'Asia',
    'Turkmenistan': 'Asia',
    'Tuvalu': 'Oceania',
    'Uganda': 'Africa',
    'Ukraine': 'Europe',
    'United Arab Emirates': 'Asia',
    'United Kingdom': 'Europe',
    'United States': 'North America',
    'Uruguay': 'South America',
    'Uzbekistan': 'Asia',
    'Vanuatu': 'Oceania',
    'Venezuela': 'South America',
    'Vietnam': 'Asia',
    'Yemen': 'Asia',
    'Zambia': 'Africa',
    'Zimbabwe': 'Africa'
}

def add_continente(pais):
    if pais in country_continents:
        return country_continents[pais]
    else:
        return np.nan   
     
df_world_data_total["continent"]=df_world_data_total["country"].apply(add_continente)

# %% [markdown]
# 3.Guarda el DataFrame después de los cambios creados después de los dos ejercicios anteriores para usarlo en el pairprogramming de mañana.

# %%
df_world_data_total.to_csv("data/df_world_data_total_apply.csv",index=False)

# %% [markdown]
# Ejercicios groupby

# %% [markdown]
# 1.¿Cuál es la densidad de población promedio por continente?

# %%
df_world_data_total.groupby("continent")["density"].mean().round(2)
# Out:
# continent
# Africa           105.09
# Asia             446.29
# Europe           798.09
# North America    188.83
# Oceania          185.00
# South America     25.00
# Name: density, dtype: float64

# %% [markdown]
# 2.¿Cuál es la esperanza de vida promedio por idioma oficial? Agrupa los países por idioma oficial y calcula la esperanza de vida promedio.

# %%
df_world_data_total.groupby(["country", "officiallanguage"])["lifeexpectancy"].mean().reset_index()
# Out:
#          country officiallanguage  lifeexpectancy
# 0    Afghanistan           Pashto            64.5
# 1        Albania         Albanian            78.5
# 2        Algeria           Arabic            76.7
# 3        Andorra          Catalan             NaN
# 4         Angola       Portuguese            60.8
# ..           ...              ...             ...
# 185    Venezuela          Spanish            72.1
# 186      Vietnam       Vietnamese            75.3
# 187        Yemen           Arabic            66.1
# 188       Zambia          English            63.5
# 189     Zimbabwe            Shona            61.2
#
# [190 rows x 3 columns]

# %% [markdown]
# 3.¿Cuál es la tasa de mortalidad infantil promedio por moneda?

# %%
df_world_data_total.groupby("currency-code")["infantmortality"].mean()
# Out:
# currency-code
# AED     6.500000
# AFN    47.900000
# ALL     7.800000
# AMD    11.000000
# AOA    51.600000
#          ...
# XCD    15.183333
# XOF    51.512500
# YER    42.900000
# ZAR    28.500000
# ZMW    40.400000
# Name: infantmortality, Length: 133, dtype: float64

# %% [markdown]
# 4.¿Cuál es el salario mínimo por continente?

# %%
df_world_data_total[["minimumwage","country"]].sample()
# Out:
#      minimumwage         country
# 185        10.13  United Kingdom

# %%
df_world_data_total.groupby("continent")["minimumwage"].min()
# Out:
# continent
# Africa           0.01
# Asia             0.05
# Europe           0.31
# North America    0.05
# Oceania          0.40
# South America    0.01
# Name: minimumwage, dtype: float64

# %% [markdown]
# 5.¿Cuál es la tasa de impuestos total máxima por densidad de población por continente? Para solucionar este ejercicio puedes:
#
# -Primero, necesitas calcular la tasa de impuestos total para cada continente. La tasa de impuestos total se encuentra en la columna "total_tax_rate".
#
# -Luego, calcula la densidad de población para cada continente. La densidad de población se encuentra en la columna "density".
#
# -Ahora, divide la tasa de impuestos total entre la densidad de población para obtener la tasa de impuestos total por persona por kilómetro cuadrado.
#
# -Encuentra el país que tiene el valor más alto en esta nueva columna calculada.

# %%
df_world_data_total.columns
# Out:
# Index(['country', 'density', 'abbreviation', 'agriculturalland', 'landarea',
#        'armedforcessize', 'birthrate', 'callingcode', 'capital/majorcity',
#        'co2-emissions', 'cpi', 'cpichange', 'currency-code', 'fertilityrate',
#        'forestedarea', 'gasolineprice', 'gdp',
#        'grossprimaryeducationenrollment', 'grosstertiaryeducationenrollment',
#        'infantmortality', 'largestcity', 'lifeexpectancy',
#        'maternalmortalityratio', 'minimumwage', 'officiallanguage',
#        'outofpockethealthexpenditure', 'physiciansperthousand', 'population',
#        'populationlaborforceparticipation', 'taxrevenue', 'totaltaxrate',
#        'unemploymentrate', 'urban_population', 'latitud', 'longitud',
#        'continent'],
#       dtype='object')

# %%
tax=df_world_data_total.groupby(["continent"])["totaltaxrate"].max()

# %%
density=df_world_data_total.groupby(["continent"])["density"].count()

# %%
(tax/density).reset_index().max()
# Out:
# continent    South America
# 0                 8.858333
# dtype: object

# %% [markdown]
# 6.¿Cuál es el porcentaje de población urbana promedio por continente?

# %%
df_world_data_total["urban_population"]
# Out:
# 0       9797273.0
# 1       1747593.0
# 2      31510100.0
# 3         67873.0
# 4      21061025.0
#           ...
# 190    25162368.0
# 191    35332140.0
# 192    10869523.0
# 193     7871713.0
# 194     4717305.0
# Name: urban_population, Length: 195, dtype: float64

# %%
df_world_data_total.groupby("continent")["urban_population"].mean()
# Out:
# continent
# Africa           1.080102e+07
# Asia             4.833283e+07
# Europe           1.322814e+07
# North America    2.002709e+07
# Oceania          2.171336e+06
# South America    2.999807e+07
# Name: urban_population, dtype: float64

# %%
# Calculamos el porcentaje de población urbana
df_world_data_total['urban_percentage'] = (df_world_data_total['urban_population'] / df_world_data_total['population']) * 100
# Calculamos el promedio por continente
porcentaje_promedio_por_continente = df_world_data_total.groupby("continent")["urban_percentage"].mean()
porcentaje_promedio_por_continente
# Out:
# continent
# Africa           45.917147
# Asia             58.930801
# Europe           72.558646
# North America    59.092484
# Oceania          48.598545
# South America    74.761018
# Name: urban_percentage, dtype: float64

# %% [markdown]
# 7.¿Cuál es la diferencia entre el PIB promedio y el gasto en salud de bolsillo promedio por idioma oficial? Para contestar esta pregunta dabes seguir los siguientes pasos:
#
# -Agrupa el DataFrame por idioma oficial y calcula la media del Gasto de Bolsillo en salud (out_of_pocket_health_expenditure) y del GPD.
#
# -Calcula la diferencia entre el PIB promedio y el gasto en salud de bolsillo promedio

# %%
gasto_salud=df_world_data_total.groupby("officiallanguage")["outofpockethealthexpenditure"].mean()

# %%
pib=df_world_data_total.groupby("officiallanguage")["gdp"].mean()

# %%
pib - gasto_salud
# Out:
# officiallanguage
# Afrikaans            3.514316e+11
# Albanian             1.527808e+10
# Amharic              9.610766e+10
# Arabic               1.366153e+11
# Armenian             1.367280e+10
#                          ...
# Tuvaluan Language    4.727146e+07
# Ukrainian            1.537811e+11
# Urdu                 3.044000e+11
# Uzbek                5.792129e+10
# Vietnamese           2.619212e+11
# Length: 76, dtype: float64

# %% [markdown]
# 8.¿Cuál es la tasa de maternidad promedio por tasa de impuestos total? Para resolver el ejercicio deberás:
#
# -Primero, calcula la tasa de maternidad promedio para cada continente. Puedes usar la columna "maternal_mortality_ratio" que representa la tasa de mortalidad materna.
#
# -Calcula la tasa de impuestos total promedio para cada continente. Puedes usar la columna "total_tax_rate" que representa la tasa de impuestos total en cada continente.
#
# -Luego, divide la tasa de maternidad promedio por la tasa de impuestos total promedio para obtener la relación entre ambas tasas.
#
# -Encuentra el país con la tasa de maternidad más alta por punto porcentual de tasa de impuestos total

# %%
maternindad_promedio=df_world_data_total.groupby("continent")["maternalmortalityratio"].mean()

# %%
impuestos_total_promedio=df_world_data_total.groupby("continent")["totaltaxrate"].mean()

# %%
maternindad_promedio/impuestos_total_promedio
# Out:
# continent
# Africa           8.750154
# Asia             2.378341
# Europe           0.200190
# North America    1.857962
# Oceania          1.632223
# South America    1.651304
# dtype: float64

# %% [markdown]
# 9.Ejercicios bonus groupby:
#
# -¿Cuál es la tasa de natalidad máxima por área forestal por continente? Encuentra el país con la tasa de natalidad más alta por cada punto porcentual de área forestal.

# %%
tasa_natalidad_max_area_forestal = df_world_data_total.groupby("continent").apply(lambda x: x["birthrate"].max() / x["landarea"].mean())

#con lambda pq quiere 2 parámetros

# %% [markdown]
# -¿Cuál es la diferencia entre la tasa de impuestos total y la tasa de desempleo promedio por continente?

# %%
# Calcula la diferencia entre la tasa de impuestos total y la tasa de desempleo promedio por continente
tasa_media_impuestos_continente = df_world_data_total.groupby('continent')['totaltaxrate'].mean()
tasa_media_desempeo_continente = df_world_data_total.groupby('continent')['unemploymentrate'].mean()

# Muestra el resultado
np.subtract(tasa_media_impuestos_continente, tasa_media_desempeo_continente)
# Out:
# continent
# Africa           39.885686
# Asia             26.376832
# Europe           32.006711
# North America    32.443684
# Oceania          35.722917
# South America    45.760833
# dtype: float64
